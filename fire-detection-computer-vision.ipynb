# %% [markdown]
# ## OVERVIEW
# ---
# * Image Preprocessing with OpenCV
#     * Masking
#     * Segmentation
#     * Image Sharpening
# * Transfer Learning with Keras Pretrained Model
# * Feature Extraction
# * Deep Learning Model to Classify the Images

# %%
import datetime as dt
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set_style('whitegrid')


import os
from keras.applications import xception
from keras.preprocessing import image
from mpl_toolkits.axes_grid1 import ImageGrid
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import cv2
from scipy.stats import uniform

from tqdm import tqdm
from glob import glob


from keras.models import Model, Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, Masking
from keras.utils import np_utils, to_categorical



from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#copying the pretrained models to the cache directory
cache_dir = os.path.expanduser(os.path.join('~', '.keras'))
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)
models_dir = os.path.join(cache_dir, 'models')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

#copy the Xception models
# !cp ../input/keras-pretrained-models/xception* ~/.keras/models/
#show
# !ls ~/.keras/models
# Out:
# xception_weights_tf_dim_ordering_tf_kernels.h5
# xception_weights_tf_dim_ordering_tf_kernels_notop.h5

# %%
base_folder = '../input/fire-dataset'
data_folder = '../input/fire-dataset/fire_dataset'
train_data_folder = '../input/fire-dataset/fire_dataset/fire_images'
test_date_folder  = '../input/fire-dataset/fire_dataset/non_fire_images'

categories = ['fire_images', 'non_fire_images']
len_categories = len(categories)

# %%
image_count = {}
train_data = []

for i , category in tqdm(enumerate(categories)):
    class_folder = os.path.join(data_folder, category)
    label = category
    image_count[category] = []
    
    for path in os.listdir(os.path.join(class_folder)):
        image_count[category].append(category)
        train_data.append(['{}/{}'.format(category, path), i, category])
# Out:
# 2it [00:00,  3.95it/s]

# %%
#show image count
for key, value in image_count.items():
    print('{0} -> {1}'.format(key, len(value)))
# Out:
# fire_images -> 755
# non_fire_images -> 244

# %%
#create a dataframe
df = pd.DataFrame(train_data, columns=['file', 'id', 'label'])
df.shape
df.head()
# Out:
# (999, 3)
#                        file  id        label
# 0  fire_images/fire.743.png   0  fire_images
# 1  fire_images/fire.717.png   0  fire_images
# 2  fire_images/fire.157.png   0  fire_images
# 3   fire_images/fire.26.png   0  fire_images
# 4  fire_images/fire.314.png   0  fire_images

# %% [markdown]
# ### IMAGE PREPROCESSING

# %%
#masking function
def create_mask_for_plant(image):
    image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    lower_hsv = np.array([0,0,250])
    upper_hsv = np.array([250,255,255])
    
    mask = cv2.inRange(image_hsv, lower_hsv, upper_hsv)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11,11))
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    
    return mask

#image segmentation function
def segment_image(image):
    mask = create_mask_for_plant(image)
    output = cv2.bitwise_and(image, image, mask = mask)
    return output/255

#sharpen the image
def sharpen_image(image):
    image_blurred = cv2.GaussianBlur(image, (0, 0), 3)
    image_sharp = cv2.addWeighted(image, 1.5, image_blurred, -0.5, 0)
    return image_sharp

# function to get an image
def read_img(filepath, size):
    img = image.load_img(os.path.join(data_folder, filepath), target_size=size)
    #convert image to array
    img = image.img_to_array(img)
    return img

# %% [markdown]
# ### SHOW SAMPLE IMAGES

# %%
nb_rows = 3
nb_cols = 5
fig, axs = plt.subplots(nb_rows, nb_cols, figsize=(10, 5));
plt.suptitle('SAMPLE IMAGES');
for i in range(0, nb_rows):
    for j in range(0, nb_cols):
        axs[i, j].xaxis.set_ticklabels([]);
        axs[i, j].yaxis.set_ticklabels([]);
        axs[i, j].imshow((read_img(df['file'][np.random.randint(1000)], (255,255)))/255.);
plt.show();

# %% [markdown]
# ### SHOW SAMPLE PROCESSED IMAGE

# %%
#get an image
img = read_img(df['file'][102],(255,255))
#mask
image_mask = create_mask_for_plant(img)
#segmentation
image_segmented = segment_image(img)
#sharpen the image
image_sharpen = sharpen_image(image_segmented)

fig, ax = plt.subplots(1, 4, figsize=(10, 5));
plt.suptitle('SAMPLE PROCESSED IMAGE', x=0.5, y=0.8)
plt.tight_layout(1)

ax[0].set_title('ORIG.', fontsize=12)
ax[1].set_title('MASK', fontsize=12)
ax[2].set_title('SEGMENTED', fontsize=12)
ax[3].set_title('SHARPEN', fontsize=12)


ax[0].imshow(img/255);
ax[1].imshow(image_mask);
ax[2].imshow(image_segmented);
ax[3].imshow(image_sharpen);

# %% [markdown]
# ### XCEPTION BOTTLENECK FEATURE EXTRACTION

# %%
INPUT_SIZE=255

##preprocess the input
X_train = np.zeros((len(df), INPUT_SIZE, INPUT_SIZE, df.shape[1]), dtype='float')
for i, file in tqdm(enumerate(df['file'])):
    #read image
    img = read_img(file,(INPUT_SIZE,INPUT_SIZE))
    #masking and segmentation
    image_segmented = segment_image(img)
    #sharpen
    image_sharpen = sharpen_image(image_segmented)
    x = xception.preprocess_input(np.expand_dims(image_sharpen.copy(), axis=0))
    X_train[i] = x
# Out:
# 999it [01:24, 11.86it/s]

# %%
print('Train Image Shape: ', X_train.shape)
print('Train Image Size: ', X_train.size)
# Out:
# Train Image Shape:  (999, 255, 255, 3)
# Train Image Size:  194879925

# %% [markdown]
# #### SPLIT THE DATA

# %%
y = df['id']
train_x, train_val, y_train, y_val = train_test_split(X_train, y, test_size=0.2, random_state=101)

# %%
print('FIRE IMAGES ON TRAINING DATA: ',y_train[y_train==0].shape[0])
print('NON-FIRE IMAGES ON TRAINING DATA: ',y_train[y_train==1].shape[0])
# Out:
# FIRE IMAGES ON TRAINING DATA:  610
# NON-FIRE IMAGES ON TRAINING DATA:  189

# %%
##get the features
xception_bf = xception.Xception(weights='imagenet', include_top=False, pooling='avg')
bf_train_x = xception_bf.predict(train_x, batch_size=32, verbose=1)
bf_train_val = xception_bf.predict(train_val, batch_size=32, verbose=1)
# Out:
# 25/25 [==============================] - 3s 108ms/step
# 7/7 [==============================] - 1s 95ms/step

# %%
#print shape of feature and size
print('Train Shape: ', bf_train_x.shape)
print('Train Size: ', bf_train_x.size)

print('Validation Shape: ', bf_train_val.shape)
print('Validation Size: ', bf_train_val.size)
# Out:
# Train Shape:  (799, 2048)
# Train Size:  1636352
# Validation Shape:  (200, 2048)
# Validation Size:  409600

# %% [markdown]
# ### DEEP LEARNING MODEL

# %%
#keras Sequential model
model = Sequential()
model.add(Dense(units = 256 , activation = 'relu', input_dim=bf_train_x.shape[1]))
model.add(Dense(units = 64 , activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))
model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 541,057
# Trainable params: 541,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model @ 100 epochs
history = model.fit(bf_train_x, y_train, epochs=100, batch_size=32);
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5367 - accuracy: 0.7472
# Epoch 2/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.7660
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.8173
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8486
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8598
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.8648
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2925 - accuracy: 0.8723
# Epoch 8/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2877 - accuracy: 0.8773
# Epoch 9/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.8824
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.8936
# Epoch 11/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2523 - accuracy: 0.8874
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2345 - accuracy: 0.9024
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.8961
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2146 - accuracy: 0.9111
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2169 - accuracy: 0.9099
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2288 - accuracy: 0.8986
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2070 - accuracy: 0.9136
# Epoch 18/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.9074
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2228 - accuracy: 0.8911
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.8886
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2095 - accuracy: 0.9086
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1790 - accuracy: 0.9262
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1888 - accuracy: 0.9186
# Epoch 24/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1674 - accuracy: 0.9324
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1639 - accuracy: 0.9374
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1600 - accuracy: 0.9274
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1669 - accuracy: 0.9287
# Epoch 28/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9337
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1714 - accuracy: 0.9199
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9399
# Epoch 31/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1602 - accuracy: 0.9362
# Epoch 32/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9349
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1922 - accuracy: 0.9111
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1989 - accuracy: 0.9049
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9324
# Epoch 36/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9237
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.9224
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1607 - accuracy: 0.9324
# Epoch 39/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9412
# Epoch 40/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1327 - accuracy: 0.9462
# Epoch 41/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1414 - accuracy: 0.9362
# Epoch 42/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9299
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.9099
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1517 - accuracy: 0.9312
# Epoch 45/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9399
# Epoch 46/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1456 - accuracy: 0.9349
# Epoch 47/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1757 - accuracy: 0.9237
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9399
# Epoch 49/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9474
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.9524
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1339 - accuracy: 0.9337
# Epoch 52/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1760 - accuracy: 0.9224
# Epoch 53/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1256 - accuracy: 0.9437
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.9362
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1247 - accuracy: 0.9462
# Epoch 56/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1281 - accuracy: 0.9449
# Epoch 57/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.9474
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 0.9399
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1344 - accuracy: 0.9412
# Epoch 60/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9499
# Epoch 61/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9499
# Epoch 62/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.9587
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9537
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1372 - accuracy: 0.9424
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.9599
# Epoch 66/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1220 - accuracy: 0.9462
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.9537
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1078 - accuracy: 0.9587
# Epoch 69/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.9512
# Epoch 70/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9274
# Epoch 71/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1648 - accuracy: 0.9136
# Epoch 72/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.9412
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9574
# Epoch 74/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.9487
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9562
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.9612
# Epoch 77/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1425 - accuracy: 0.9312
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9487
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1353 - accuracy: 0.9312
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9499
# Epoch 81/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 0.9512
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9650
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.9599
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9650
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1374 - accuracy: 0.9387
# Epoch 86/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.9625
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9537
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9637
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9574
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1388 - accuracy: 0.9312
# Epoch 91/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9462
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9637
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9562
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 0.9662
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9324
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9537
# Epoch 97/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9625
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9625
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.9612
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0827 - accuracy: 0.9662

# %% [markdown]
# #### LOSS AND ACCURACY

# %%
fig, ax = plt.subplots(1,2,figsize=(14,5))
ax[0].set_title('TRAINING LOSS');
ax[1].set_title('TRAINING ACCURACY');


ax[0].plot(history.history['loss'], color= 'salmon',lw=2);
ax[1].plot(history.history['accuracy'], color= 'green',lw=2);

# %%
#predict the validation data
predictions = model.predict_classes(bf_train_val)

# %% [markdown]
# #### CLASSIFICATION REPORT

# %%
print(classification_report(y_val, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       145
#            1       0.84      0.78      0.81        55
#
#     accuracy                           0.90       200
#    macro avg       0.88      0.86      0.87       200
# weighted avg       0.90      0.90      0.90       200

# %% [markdown]
# #### CONFUSION MATRIX

# %%
confusion_mat = confusion_matrix(y_val, predictions)

plt.figure(figsize=(10,10))
sns.heatmap(confusion_mat, square=True, annot=True,
            yticklabels=['FIRE_IMG', 'NON_FIRE_IMG'],
            xticklabels=['FIRE_IMG', 'NON_FIRE_IMG']);
plt.title('CONFUSION MATRIX');
plt.xlabel('Y_TRUE');
plt.ylabel("PREDICTIONS");
